# %%
# Integer Example
age = 28
type(age)

# %%
# flaot Datatype 
height = 6.9
type(height)

# %%
# string datatype
name = "shahbaz"
type(name)

# %%
# bool data type
is_true= False
type(is_true)

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
# result = "name" + 6
result = "name" + str(6)
print (result)
# Out:
# name6

# %%
lst=["make tea","buy grocerires"]


for todo in lst :
    if "make tea" in lst:
        lst.remove("make tea")
    print("tea is compelted")
    
print(lst)

# %%
lst=["make tea","buy grocerires"]


for todo in lst :
    if "make tea" in lst:
        lst.remove("make tea")
    print("tea is compelted")
    
print(lst)

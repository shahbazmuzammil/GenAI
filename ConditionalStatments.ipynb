# %%
age = 20

if age>=18:
    print("your become a voter")
# Out:
# your become a voter

# %%
# else 
age = 18
if age>=18:
    print(' vote')
else :
    print("cant")
# Out:
# cant vote

# %%
# elif statement
# it allows you to check multiple condition it stand for else if
age = 89
if age>=90:
    print("old")
elif age>88:
    print("old")
else:
    print("young")
# Out:
# old

# %%
# Nested Conditional statment 
# you can place one ot more if elif or else statment inside annother if elif or else statment yo nested constion

# number even odd negative
num = int(input("enter the number"))

if num>=0:
    print("this is nnumber is bengative")
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")
    
else :
    print('the number is zero negative')
# Out:
# this is nnumber is bengative
# the number is odd

# %%
# practical example
# determine if a year is a lean=p year using the nested condition
year = int(input("enter the year"))

if year%4==0:
    # if year%100==0:
    #     if year%400==0:
            print(year,"is leap year")
    #     else: 
    #         print(year,"is not a leap year")
    # else:
    #     print(year,"is aleap year")
else: 
    print(year,"is not leap year")
# Out:
# 3024 is leap year

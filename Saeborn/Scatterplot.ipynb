# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# help(pd.DataFrame)
df=pd.read_csv('dm_office_sales.csv')

df.head()
# plt.figure(figsize=(10,6)dpi=100)
# Out:
#          Date Office Location        Product  Quantity  Sales Amount  \
# 0  2026-01-05        New York     Desk Chair         5          2500
# 1  2026-01-06     Los Angeles  Monitor Stand         8          1200
# 2  2026-01-07         Chicago      Desk Lamp        12           840
# 3  2026-01-08        New York       Keyboard        15           750
# 4  2026-01-09         Houston      Mouse Pad        20           400
#
#     Sales Person
# 0     John Smith
# 1  Sarah Johnson
# 2  Michael Brown
# 3     John Smith
# 4    Emily Davis

# %%
sns.scatterplot(data=df,x='Sales Amount',y='Quantity',size='Quantity',s=200,alpha=5,style='Sales Amount',hue='Quantity')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.scatterplot(data=df,x='Sales Amount',y='Quantity',size='Quantity',s=200,alpha=5,style='Sales Amount',hue='Quantity')
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\relational.py:438, in _ScatterPlotter.plot(self, ax, kws)
#     435     kws.setdefault("edgecolor", "w")
#     437 # Draw the scatter plot
# --> 438 points = ax.scatter(x=x, y=y, **kws)
#     440 # Apply the mapping from semantic variables to artist attributes
#     442 if "hue" in self.variables:
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\axes\_axes.py:5025, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    5019         linewidths = [
#    5020             lw if lw is not None else mpl.rcParams['lines.linewidth']
#    5021             for lw in linewidths]
#    5023 offsets = np.ma.column_stack([x, y])
# -> 5025 collection = mcoll.PathCollection(
#    5026     (path,), scales,
#    5027     facecolors=colors,
#    5028     edgecolors=edgecolors,
#    5029     linewidths=linewidths,
#    5030     offsets=offsets,
#    5031     offset_transform=kwargs.pop('transform', self.transData),
#    5032     alpha=alpha,
#    5033 )
#    5034 collection.set_transform(mtransforms.IdentityTransform())
#    5035 if colors is None:
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\collections.py:1030, in PathCollection.__init__(self, paths, sizes, **kwargs)
#    1016 def __init__(self, paths, sizes=None, **kwargs):
#    1017     """
#    1018     Parameters
#    1019     ----------
#    (...)   1027         Forwarded to `.Collection`.
#    1028     """
# -> 1030     super().__init__(**kwargs)
#    1031     self.set_paths(paths)
#    1032     self.set_sizes(sizes)
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\collections.py:209, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, colorizer, pickradius, hatch, urls, zorder, **kwargs)
#     206 self._offset_transform = offset_transform
#     208 self._path_effects = None
# --> 209 self._internal_update(kwargs)
#     210 self._paths = None
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\collections.py:851, in Collection.set_alpha(self, alpha)
#     839 def set_alpha(self, alpha):
#     840     """
#     841     Set the transparency of the collection.
#     842
#    (...)    849         supported.
#     850     """
# --> 851     artist.Artist._set_alpha_for_array(self, alpha)
#     852     self._set_facecolor(self._original_facecolor)
#     853     self._set_edgecolor(self._original_edgecolor)
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\artist.py:1045, in Artist._set_alpha_for_array(self, alpha)
#    1043     raise TypeError("alpha must be numeric or None, not a string")
#    1044 if not np.iterable(alpha):
# -> 1045     Artist.set_alpha(self, alpha)
#    1046     return
#    1047 alpha = np.asarray(alpha)
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\matplotlib\artist.py:1026, in Artist.set_alpha(self, alpha)
#    1023     raise TypeError(
#    1024         f'alpha must be numeric or None, not {type(alpha)}')
#    1025 if alpha is not None and not (0 <= alpha <= 1):
# -> 1026     raise ValueError(f'alpha ({alpha}) is outside 0-1 range')
#    1027 if alpha != self._alpha:
#    1028     self._alpha = alpha
#
# ValueError: alpha (5) is outside 0-1 range

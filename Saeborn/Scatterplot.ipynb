# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# help(pd.DataFrame)
df=pd.read_csv('dm_office_sales.csv')

df.head()
# plt.figure(figsize=(10,6)dpi=100)
# Out:
#          Date Office Location        Product  Quantity  Sales Amount  \
# 0  2026-01-05        New York     Desk Chair         5          2500
# 1  2026-01-06     Los Angeles  Monitor Stand         8          1200
# 2  2026-01-07         Chicago      Desk Lamp        12           840
# 3  2026-01-08        New York       Keyboard        15           750
# 4  2026-01-09         Houston      Mouse Pad        20           400
#
#     Sales Person
# 0     John Smith
# 1  Sarah Johnson
# 2  Michael Brown
# 3     John Smith
# 4    Emily Davis

# %%
sns.scatterplot(data=df,x='Sales Amount',y='Quantity',size='Quantity',s=200,alpha=0.5,style='Sales Amount',hue='Quantity')
# Out:
# <Axes: xlabel='Sales Amount', ylabel='Quantity'>

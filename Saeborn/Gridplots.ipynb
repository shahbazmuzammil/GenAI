# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('student_exam_data.csv')
df.head()
# Out:
#    Gender Race/Ethnicity Parental Level of Education     Lunch  \
# 0  Female        Group B           Bachelor's Degree  Standard
# 1    Male        Group C                Some College      Free
# 2  Female        Group A             Master's Degree  Standard
# 3    Male        Group B          Associate's Degree      Free
# 4  Female        Group C            Some High School  Standard
#
#   Test Preparation Course  Math Score  Reading Score  Writing Score
# 0           Not Completed          72             73             74
# 1               Completed          69             90             88
# 2           Not Completed          90             95             93
# 3           Not Completed          47             57             56
# 4           Not Completed          76             78             75

# %%
sns.catplot(x='Math Score', y='Writing Score',data=df,kind='violin',col='Lunch',row='Race/Ethnicity',palette='Set2')
# Out:
# C:\Users\l\AppData\Local\Temp\ipykernel_13040\2942713728.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Math Score', y='Writing Score',data=df,kind='violin',col='Lunch',row='Race/Ethnicity',palette='Set2')

# %%
g= sns.PairGrid(df,hue='Gender')
g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.kdeplot)
g = g.map_lower(sns.kdeplot, cmap='Blues_d')
# g = g.map_diag(sns.histplot)
# g = g.map_offdiag(sns.scatterplot)

g=g.add_legend()
# Out:
# c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

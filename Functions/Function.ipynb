# %% [markdown]
# function
# Function is a block of code that performs a specific task function help in oraganizing code resulting ad improving readability

# %%
def print_details(*args, **kwargs):
    for val in args:
        print(f"Positional argument:{val}")
    for key, value in kwargs.items():
        print(f"{key}:{value}")

# %%
# ...existing code...
def print_details(*args, **kwargs):
    for val in args:
        print(f"Positional argument:{val}")
    for key, value in kwargs.items():
        print(f"{key}:{value}")

val = print_details(1, 2, 3, 4, "shahbaz", name="zainab", age="3")
print(val)
# ...existing code...
# Out:
# Positional argument:1
# Positional argument:2
# Positional argument:3
# Positional argument:4
# Positional argument:shahbaz
# name:zainab
# age:3
# None

# %%
def is_Strong_password(password):
    if len(password)<8:
        return False
    if not any(char.isdigit()  for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char in "!@#$%^&*()-_+" for char in password):
        return False
    return True
password=is_Strong_password(input("Enter your password:"))
print(password)
# Out:
# True

# %%
def calculate_total_cost(cart):
    total_cost=0
    for item in cart:
        total_cost += item['price'] * item['quantity']
    return total_cost
cart = [
    {'name': 'apple', 'price': 0.5, 'quantity': 4},
    {'name': 'banana', 'price': 0.3, 'quantity': 6},
    {'name': 'orange', 'price': 0.8, 'quantity': 3}
]
total = calculate_total_cost(cart)
print(f"Total cost: ${total:.2f}")
# Out:
# Total cost: $6.20

# %%
def is_palindrome(s):
    s = s.replace(" ", "").lower()
    return s == s[::-1]
print(is_palindrome("A man a plan a canal Panama"))  # True
print(is_palindrome("Hello"))  # False
# Out:
# True
# False

# %%
def count_word_frequency(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    words = text.split()
    frequency = {}
    for word in words:
        word = word.lower().strip(".,!?\"'()[]{};:")
        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1
    return frequency
print(count_word_frequency('sample.txt'))  # Replace 'sample.txt' with your file path
# Out:
# {'hellow': 1, 'ahiubc': 1, 'jasbc': 1}

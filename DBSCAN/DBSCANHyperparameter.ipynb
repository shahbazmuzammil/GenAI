# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
print("dsnbcjjdscn")
# Out:
# dsnbcjjdscn

# %%
two_blobs = pd.read_csv('./cluster_two_blobs.csv')

# %%
two_blobs_outliers = pd.read_csv('./cluster_two_blobs_outliers.csv')

# %%
two_blobs_outliers

# %%
sns.scatterplot(data=two_blobs,x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
# two_blobs_outliers
def display_categories(model,data):
    labels = model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN()

# %%
display_categories(dbscan,two_blobs)

# %%
num_dim = two_blobs_outliers.shape[1]
dbscan = DBSCAN(min_samples=2*num_dim,eps=0.75)
display_categories(dbscan,two_blobs_outliers)

# %%
len(np.unique(dbscan.labels_))
# Out:
# 1

# %%
#CHeck total outalier found
np.sum(dbscan.labels_ == -1)
# Out:
# np.int64(3)

# %%
100 * np.sum(dbscan.labels_ == -1) / len(dbscan.labels_)
# Out:
# np.float64(0.29910269192422734)

# %%
len(dbscan.labels_)
# Out:
# 1003

# %%
outlier_precent = []
number_of_outlier = []
for n in np.arange(1,100):
    dbscan = DBSCAN(min_samples=n)
    dbscan.fit(two_blobs_outliers)
    #Total Outlier Found
    number_of_outlier.append(np.sum(dbscan.labels_ == -1))
    # Percent of points calssified as outliers
    perc_outliers = 100 * np.sum(dbscan.labels_ == -1)/len(dbscan.labels_)
    outlier_precent.append(perc_outliers)

# %%
sns.lineplot(x=np.arange(1,100),y=number_of_outlier)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
sns.lineplot(x=np.linspace(0.001,7,200),y=number_of_outlier)
plt.hlines(y=3,xmin=0,xmax=2,colors='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.lineplot(x=np.linspace(0.001,7,200),y=number_of_outlier)
#       2 plt.hlines(y=3,xmin=0,xmax=2,colors='red')
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
# ...

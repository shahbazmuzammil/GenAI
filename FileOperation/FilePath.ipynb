# %%
#create a new directory
import os
new_directory = "package_data"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created.")

# %%
#Listing Files and Directories
items=os.listdir('.')
print(items)
# Out:
# ['binaryfile.bin', 'FileOperation.ipynb', 'FilePath.ipynb', 'kabom.csv', 'kaboom.csv', 'kaboom.txt', 'package_data', 'quickfile.txt', 'source.txt']

# %%
#joining paths
dir_name="folder"
file_name="data.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\l\OneDrive\Documents\GenAIPython\FileOperation\folder\data.txt

# %%
path="C:/Users/l/OneDrive/Documents/GenAIPython/FileOperation/kaboom.csv"
if os.path.exists(path):
    print("The file exists.")
else:
    print("The file does not exist.")
# Out:
# The file exists.

# %%
print(os.path.isfile(path))
print(os.path.isdir(path))
# Out:
# True
# False

# %%
#getting absolute path
absolute_path=os.path.abspath("kaboom.csv")
print(absolute_path)

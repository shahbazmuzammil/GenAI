# %% [markdown]
# Importing Modules in python: Modules and Packages
# In Python,modules and Packages help organize and reuse code. Here's a comrehensive guide on how to import them.

# %%
import numpy as np

np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
from math import *
print(sqrt(16))

print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
#High level operations on files and collections of files
from package.maths import addition
print(addition(5,7))
# print(subtractions(10,4))
# Out:
# 12

# %%
#Data Serialization
import json
data = {'name': 'Alice', 'age': 30, 'city': 'New York'}
json_data = json.dumps(data)   
print(json_data)
parsed_data = json.loads(json_data)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}
# {'name': 'Alice', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
import csv
import os

with open('data.csv', mode='w', newline='') as file:
    csv_writer = csv.writer(file)
    csv_writer.writerow(['Name', 'Age', 'City'])    
    csv_writer.writerow(['Alice', 30, 'New York'])
    csv_writer.writerow(['Bob', 25, 'Los Angeles'])
    
with open('data.csv', mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']

# %%
#Time
import time
print("Current Time:", time.ctime())
time.sleep(2)
print("Time after 2 seconds:", time.ctime())
# Out:
# Current Time: Wed Dec 31 23:21:33 2025
# Time after 2 seconds: Wed Dec 31 23:21:35 2025

# %%
# regular expressions
import re       
pattern = r'\b\d{3}-\d{2}-\d{4}\b'
text = "My SSN is 123-45-6789."
match = re.search(pattern, text)
print("Found SSN:", match.group())
# Out:
# Found SSN: 123-45-6789

# %%
#dateTime
from datetime import datetime, timedelta
now=datetime.now()
print("Current Date and Time:", now)
yesterday=now - timedelta(days=1)
print("Yesterday's Date and Time:", yesterday)
# Out:
# Current Date and Time: 2025-12-31 23:19:52.220507
# Yesterday's Date and Time: 2025-12-30 23:19:52.220507

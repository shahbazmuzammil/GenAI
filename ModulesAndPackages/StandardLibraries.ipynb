# %% [markdown]
# Standard Library Overview

# %%
import array 
print(array.array('i', [1, 2, 3, 4, 5]))
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(25))
print(math.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import random
print(random.randint(1, 1156546))
print(random.choice(['apple', 'banana', 'cherry']))
print(random.random())
# Out:
# 737269
# banana
# 0.5746473056621767

# %%
import os
print(os.getcwd())
print(os.listdir('.'))
# print(os.mkdir('tst_dir'))
# Out:
# c:\Users\l\OneDrive\Documents\GenAIPython\ModulesAndPackages
# ['ModuleAndPackage.ipynb', 'package', 'StandardLibraries.ipynb', 'test.py', 'tst_dir']
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[66], line 4
#       2 print(os.getcwd())
#       3 print(os.listdir('.'))
# ----> 4 print(os.mkdir('tst_dir'))
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'tst_dir'

# %%
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

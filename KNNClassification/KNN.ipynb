# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('Libraries imported')
# Out:
# Libraries imported

# %%
df = pd.read_csv("./gene_expression (1).csv")
print('columns:', df.columns.tolist())
print(df.head(3))
# Out:
#        Gene One  Gene Two  Cancer Present
# 0           4.3       3.9               1
# 1           2.5       6.3               0
# 2           5.7       3.9               1
# 3           6.1       6.2               0
# 4           7.4       3.4               1

# %%
df
# Out:
#           Gene One  Gene Two  Cancer Present
# 0              4.3       3.9               1
# 1              2.5       6.3               0
# 2              5.7       3.9               1
# 3              6.1       6.2               0
# 4              7.4       3.4               1
# ...            ...       ...             ...
# 2995           5.0       6.5               1
# 2996           3.4       6.6               0
# 2997           2.7       6.5               0
# 2998           3.3       5.6               0
# 2999           4.6       8.2               0
#
# [3000 rows x 3 columns]

# %%
sns.scatterplot(data=df,x="Gene One",y="Gene Two",hue="Cancer Present",style="Cancer Present",alpha=0.6)
plt.xlim(1,8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.scatterplot(data=df,x="Gene One",y="Gene Two",hue="Cancer Present",style="Cancer Present",alpha=0.6)
#       2 plt.xlim(1,8)
#
# File c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
sns.pairplot(data=df,hue='Cancer Present')

# %%
X = df.drop('Cancer Present',axis=1)

# %%
y=df['Cancer Present']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,train_size=101)

# %%
scaler  = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
scaled_X_test

# %%
scaled_X_test

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN_neighbor = KNeighborsClassifier()

# 2. Fit the model on the scaled training data
KNN_neighbor.fit(scaled_X_train, y_train)

# 3. Predict the labels for the test dataset
y_predict_KN = KNN_neighbor.predict(scaled_X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_test,y_predict_KN)

# %%
KNN_neighbor = KNeighborsClassifier()

# 2. Fit the model on the scaled training data
KNN_neighbor.fit(scaled_X_train, y_train)

# 3. Predict the labels for the test dataset
y_predict_KN = KNN_neighbor.predict(scaled_X_test)
scaler  = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
test_error= []
for k in range(1,30):
    
    KNN_model = KNeighborsClassifier(n_neighbors=k)
    KNN_model.fit(scaled_X_test,y_train)
    KNN_predict = KNN_model.predict(scaled_X_test)
    KNN_accu=1-accuracy_score(test_error)
    test_error.append(KNN_accu)
    print(test_error)

# %% [markdown]
# PIPLINE ----> GridsearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.preprocessing import StandardScaler

# %%
KNN = KNeighborsClassifier()

# %%
scaler = StandardScalar()

# %%
from sklearn.pipline import Pipiline

# %%
operations = {('scaler',scaler),('KNN',KKN)}

# %%
pipe = Pipeline(operations)

# %%
from sklearn.model_selection import GridSearchCV

# %%
k_values=List(range(1,20))

# %%
params = {'KNN__n_neighbors':k_values}

# %%
full_cv_classifier = GridSearchCV(pipe,params,cv=5,scoring='accuracy')

# %%
full_cv_classifier.fit(X_train,y_train)

# %%
full_cv_classifier.best_estimator_.get_params()

# %%
full_pred=full_cv_classifier.predict(X_test)

# %%
print(classification_report(y_test,full_pred))

# %%
new_patient = [[3.8,6.4]]

# %%
full_cv_classifier.predict(new_patient)

# %%
full_cv_classifier.predict_prob(new_patient)

# %%
full_pred = full_cv_classifier.predict(X_test)

# %%
print(classification_report(y_train,full_pred
                            ))

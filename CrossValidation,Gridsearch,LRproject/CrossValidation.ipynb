# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
df = pd.read_csv("./Advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X= df.drop("sales",axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 3.8371832916882265

# %%
model_two= Ridge(alpha=0)

# %%
model_two.fit(X_train,y_train)
# Out:
# Ridge(alpha=0)

# %%
y_pred_two= model_two.predict(X_test)

# %%
mean_squared_error(y_test,y_pred_two)
# Out:
# 3.847309393835302

# %% [markdown]
# CROSS VALIDATION - TEST | VALIDATION | TRAIN SPLIT

# %%
df = pd.read_csv("./Advertising.csv")
df.head()
X= df.drop("sales",axis=1)
y=df['sales']

# %%
X= df.drop("sales",axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_other,y_train,y_other = train_test_split(X,y,test_size=0.3,random_state=101)
X_eval,X_other,y_eval,y_other = train_test_split(X_other,y_other,test_size=0.5,random_state=101)

# %%
len(df)
# Out:
# 200

# %%
print(f"Training set: {len(X_train)} samples")
print(f"Evaluation set: {len(X_eval)} samples")
print(f"Test set: {len(X_other)} samples")
print(f"Total samples: {len(X_train) + len(X_eval) + len(X_other)}")
# Out:
# Training set: 140 samples
# Evaluation set: 30 samples
# Test set: 30 samples
# Total samples: 200

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_eval_scaled = scaler.transform(X_eval)
X_other = scaler.transform(X_other)

# %%
from sklearn.linear_model import Ridge

# %%
model_one = Ridge(alpha=100)

# %%
model_one.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model_one.predict(X_eval)

# %%
import sklearn.metrics as metrics
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 2.4448963401720474

# %%
model_two = Ridge(alpha=1)

# %%
model_two.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
new_pred_eval = model_two.predict(X_eval)

# %%
mean_squared_error(y_eval,new_pred_eval)
# Out:
# 2.445646246159606

# %% [markdown]
# CROSS_VAL_SCORE Function

# %%
df = pd.read_csv("./Advertising.csv")
df.head()
X= df.drop("sales",axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_other = scaler.transform(X_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model,X_train_scaled,y_train,cv=5,scoring = 'neg_mean_squared_error')

# %%
scores
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(scores.mean())
# Out:
# np.float64(8.215396464543607)

# %%
model = Ridge(alpha=1)
scores = cross_val_score(model,X_train_scaled,y_train,cv=5,scoring = 'neg_mean_squared_error')

# %%
print(scores)
abs(scores.mean())
# Out:
# [-3.15513238 -1.58086982 -5.40455562 -2.21654481 -4.36709384]
# np.float64(3.344839296530695)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final_test_pred)
# Out:
# 2.3433176384798453

# %% [markdown]
# Cross_Validate - Function

# %%
df = pd.read_csv("./Advertising.csv")
df.head()
X= df.drop("sales",axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_other = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(
    model,
    X_train,
    y_train,
    scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'],
    cv=10,
    return_train_score=False
)
# Out:
# [-2.98808146 -3.03690267 -2.21035783 -0.84123941 -3.46322456 -8.18348698
#  -1.94733955 -2.75918475 -4.94543978 -2.83808028]
# [-1.45950287 -1.55653459 -1.24509581 -0.76094303 -1.42617571 -1.48376277
#  -1.0963538  -1.25928741 -1.57214754 -1.22547171]

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.016828    0.005298                    -2.988081
# 1  0.003778    0.001590                    -3.036903
# 2  0.001664    0.001376                    -2.210358
# 3  0.001678    0.002641                    -0.841239
# 4  0.001797    0.002448                    -3.463225
# 5  0.001997    0.001461                    -8.183487
# 6  0.001518    0.001250                    -1.947340
# 7  0.001726    0.001256                    -2.759185
# 8  0.002647    0.001764                    -4.945440
# 9  0.002555    0.001318                    -2.838080
#
#    test_neg_mean_absolute_error
# 0                     -1.459503
# 1                     -1.556535
# 2                     -1.245096
# 3                     -0.760943
# 4                     -1.426176
# 5                     -1.483763
# 6                     -1.096354
# 7                     -1.259287
# 8                     -1.572148
# 9                     -1.225472

# %%
scores.mean()
# Out:
# fit_time                        0.003619
# score_time                      0.002040
# test_neg_mean_squared_error    -3.321334
# test_neg_mean_absolute_error   -1.308528
# dtype: float64

# %%
model = Ridge(alpha=1)
from sklearn.model_selection import cross_validate

scores = cross_validate(
    model,
    X_train,
    y_train,
    scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'],
    cv=10,
    return_train_score=False
)
scores = pd.DataFrame(scores)
abs(scores.mean())
# Out:
# fit_time                        0.002723
# score_time                      0.002209
# test_neg_mean_squared_error     3.322105
# test_neg_mean_absolute_error    1.307760
# dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final_pred)
# Out:
# 2.3433176384798453

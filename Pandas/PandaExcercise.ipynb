# %%
import pandas as pd
hotels=pd.read_csv('hotel_booking_data.csv')
hotels.head()
# Out:
#   BookingID      CustomerName          HotelName CheckInDate CheckOutDate  \
# 0     B1001        John Smith  Grand Plaza Hotel  2025-01-20   2025-01-25
# 1     B1002      Maria Garcia  Ocean View Resort  2025-02-01   2025-02-08
# 2     B1003      Ahmed Hassan          Taj Hotel  2025-01-15   2025-01-18
# 3     B1004       Emma Wilson   Eiffel Tower Inn  2025-02-10   2025-02-15
# 4     B1005  Carlos Rodriguez    Cancun Paradise  2025-01-25   2025-02-02
#
#    RoomType  NumGuests  NightCount  PricePerNight  TotalPrice      City  \
# 0    Deluxe          2           5            150         750  New York
# 1     Suite          3           7            200        1400     Miami
# 2  Standard          1           3             80         240     Delhi
# 3    Deluxe          2           5            180         900     Paris
# 4     Suite          4           8            220        1760    Cancun
#
#   Country     Status  Rating CancellationDate
# ...

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BookingID         20 non-null     object
#  1   CustomerName      20 non-null     object
#  2   HotelName         20 non-null     object
#  3   CheckInDate       20 non-null     object
#  4   CheckOutDate      20 non-null     object
#  5   RoomType          20 non-null     object
#  6   NumGuests         20 non-null     int64
#  7   NightCount        20 non-null     int64
#  8   PricePerNight     20 non-null     int64
#  9   TotalPrice        20 non-null     int64
#  10  City              20 non-null     object
#  11  Country           20 non-null     object
#  12  Status            20 non-null     object
#  13  Rating            8 non-null      float64
#  14  CancellationDate  2 non-null      object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 2.5+ KB

# %% [markdown]
# is there any missing data

# %%
hotels.isnull().sum()
# Out:
# BookingID            0
# CustomerName         0
# HotelName            0
# CheckInDate          0
# CheckOutDate         0
# RoomType             0
# NumGuests            0
# NightCount           0
# PricePerNight        0
# TotalPrice           0
# City                 0
# Country              0
# Status               0
# Rating              12
# CancellationDate    18
# dtype: int64

# %%
# drop the NightCount column from the table 
# hotels.drop('NightCount',axis=1)
# Out:
#    BookingID      CustomerName             HotelName CheckInDate CheckOutDate  \
# 0      B1001        John Smith     Grand Plaza Hotel  2025-01-20   2025-01-25
# 1      B1002      Maria Garcia     Ocean View Resort  2025-02-01   2025-02-08
# 2      B1003      Ahmed Hassan             Taj Hotel  2025-01-15   2025-01-18
# 3      B1004       Emma Wilson      Eiffel Tower Inn  2025-02-10   2025-02-15
# 4      B1005  Carlos Rodriguez       Cancun Paradise  2025-01-25   2025-02-02
# 5      B1006     Sophie Martin      Swiss Alps Lodge  2025-02-05   2025-02-12
# 6      B1007       James Brown    Tokyo Metropolitan  2025-01-28   2025-02-05
# 7      B1008         Lisa Chen     Bali Beach Resort  2025-02-15   2025-02-22
# 8      B1009       Marco Rossi   Rome Historic Hotel  2025-02-20   2025-02-25
# 9      B1010     Anna Kowalski   Warsaw Palace Hotel  2025-03-01   2025-03-08
# 10     B1011    David Thompson    Sydney Harbor View  2025-01-30   2025-02-06
# ...

# %%
# what are the top 5 most common code
hotels['RoomType'].value_counts()[:5]
hotels.groupby('RoomType').count()
# Out:
#           BookingID  CustomerName  HotelName  CheckInDate  CheckOutDate  \
# RoomType
# Deluxe            6             6          6            6             6
# Standard          7             7          7            7             7
# Suite             7             7          7            7             7
#
#           NumGuests  NightCount  PricePerNight  TotalPrice  City  Country  \
# RoomType
# Deluxe            6           6              6           6     6        6
# Standard          7           7              7           7     7        7
# Suite             7           7              7           7     7        7
#
#           Status  Rating  CancellationDate
# RoomType
# Deluxe         6       2                 2
# Standard       7       4                 0
# Suite          7       2                 0

# %%
# what is the cutomer name who pays hieght TotalPrice	
# hotels.sort_values('TotalPrice')[['TotalPrice','CustomerName']]
hotels['TotalPrice'].max()
hotels.iloc[hotels['TotalPrice'].idxmax()]
# Out:
# BookingID                          B1016
# CustomerName               Pierre Dubois
# HotelName           Monaco Luxury Resort
# CheckInDate                   2025-03-05
# CheckOutDate                  2025-03-12
# RoomType                           Suite
# NumGuests                              2
# NightCount                             7
# PricePerNight                        300
# TotalPrice                          2100
# City                              Monaco
# Country                           France
# Status                         Confirmed
# Rating                               NaN
# CancellationDate                     NaN
# Name: 15, dtype: object

# %%
# The Price of avrage daily rate for a person stay at the hotel what is the mean of the total price across the hotel statys in dataset
hotels['TotalPrice'].mean()
hotels
# Out:
#    BookingID      CustomerName             HotelName CheckInDate CheckOutDate  \
# 0      B1001        John Smith     Grand Plaza Hotel  2025-01-20   2025-01-25
# 1      B1002      Maria Garcia     Ocean View Resort  2025-02-01   2025-02-08
# 2      B1003      Ahmed Hassan             Taj Hotel  2025-01-15   2025-01-18
# 3      B1004       Emma Wilson      Eiffel Tower Inn  2025-02-10   2025-02-15
# 4      B1005  Carlos Rodriguez       Cancun Paradise  2025-01-25   2025-02-02
# 5      B1006     Sophie Martin      Swiss Alps Lodge  2025-02-05   2025-02-12
# 6      B1007       James Brown    Tokyo Metropolitan  2025-01-28   2025-02-05
# 7      B1008         Lisa Chen     Bali Beach Resort  2025-02-15   2025-02-22
# 8      B1009       Marco Rossi   Rome Historic Hotel  2025-02-20   2025-02-25
# 9      B1010     Anna Kowalski   Warsaw Palace Hotel  2025-03-01   2025-03-08
# 10     B1011    David Thompson    Sydney Harbor View  2025-01-30   2025-02-06
# ...

# %%
# what is the avarage of people stays at night
hotels['NightAverage']=hotels['NightCount'].mean()
hotels
# Out:
#    BookingID      CustomerName             HotelName CheckInDate CheckOutDate  \
# 0      B1001        John Smith     Grand Plaza Hotel  2025-01-20   2025-01-25
# 1      B1002      Maria Garcia     Ocean View Resort  2025-02-01   2025-02-08
# 2      B1003      Ahmed Hassan             Taj Hotel  2025-01-15   2025-01-18
# 3      B1004       Emma Wilson      Eiffel Tower Inn  2025-02-10   2025-02-15
# 4      B1005  Carlos Rodriguez       Cancun Paradise  2025-01-25   2025-02-02
# 5      B1006     Sophie Martin      Swiss Alps Lodge  2025-02-05   2025-02-12
# 6      B1007       James Brown    Tokyo Metropolitan  2025-01-28   2025-02-05
# 7      B1008         Lisa Chen     Bali Beach Resort  2025-02-15   2025-02-22
# 8      B1009       Marco Rossi   Rome Historic Hotel  2025-02-20   2025-02-25
# 9      B1010     Anna Kowalski   Warsaw Palace Hotel  2025-03-01   2025-03-08
# 10     B1011    David Thompson    Sydney Harbor View  2025-01-30   2025-02-06
# ...

# %%
hotels['CancellationDate'].value_counts().notnull()
# Out:
# CancellationDate
# 2025-01-25    True
# 2025-02-10    True
# Name: count, dtype: bool

# %%
hotels
# avarage total cost for a stay in the hotel in the dataset total stay cost 
hotels['total_spend']=hotels['TotalPrice']/ hotels['NightCount'].mean()
hotels
# Out:
#    BookingID      CustomerName             HotelName CheckInDate CheckOutDate  \
# 0      B1001        John Smith     Grand Plaza Hotel  2025-01-20   2025-01-25
# 1      B1002      Maria Garcia     Ocean View Resort  2025-02-01   2025-02-08
# 2      B1003      Ahmed Hassan             Taj Hotel  2025-01-15   2025-01-18
# 3      B1004       Emma Wilson      Eiffel Tower Inn  2025-02-10   2025-02-15
# 4      B1005  Carlos Rodriguez       Cancun Paradise  2025-01-25   2025-02-02
# 5      B1006     Sophie Martin      Swiss Alps Lodge  2025-02-05   2025-02-12
# 6      B1007       James Brown    Tokyo Metropolitan  2025-01-28   2025-02-05
# 7      B1008         Lisa Chen     Bali Beach Resort  2025-02-15   2025-02-22
# 8      B1009       Marco Rossi   Rome Historic Hotel  2025-02-20   2025-02-25
# 9      B1010     Anna Kowalski   Warsaw Palace Hotel  2025-03-01   2025-03-08
# 10     B1011    David Thompson    Sydney Harbor View  2025-01-30   2025-02-06
# ...

# %%
# what are the number people stays in the delux room

hotels.groupby(['RoomType','CustomerName']).count()
# Out:
#                            BookingID  HotelName  CheckInDate  CheckOutDate  \
# RoomType CustomerName
# Deluxe   Anna Kowalski             1          1            1             1
#          Emma Wilson               1          1            1             1
#          James Brown               1          1            1             1
#          John Smith                1          1            1             1
#          Michael O'Brien           1          1            1             1
#          Roberto Silva             1          1            1             1
# Standard Ahmed Hassan              1          1            1             1
#          Helena Schmidt            1          1            1             1
#          Lucia Moretti             1          1            1             1
#          Marco Rossi               1          1            1             1
#          Michelle Lee              1          1            1             1
# ...

# %%
hotels[-5:]
# Out:
#    BookingID     CustomerName             HotelName CheckInDate CheckOutDate  \
# 15     B1016    Pierre Dubois  Monaco Luxury Resort  2025-03-05   2025-03-12
# 16     B1017     Priya Sharma  Mumbai Gateway Hotel  2025-01-22   2025-01-26
# 17     B1018  Michael O'Brien   Dublin Temple Hotel  2025-03-15   2025-03-22
# 18     B1019    Lucia Moretti  Florence Renaissance  2025-02-28   2025-03-07
# 19     B1020    Antonio Gomez  Barcelona Beachfront  2025-03-20   2025-03-27
#
#     RoomType  NumGuests  NightCount  PricePerNight  TotalPrice       City  \
# 15     Suite          2           7            300        2100     Monaco
# 16  Standard          2           4             85         340     Mumbai
# 17    Deluxe          1           7            155        1085     Dublin
# 18  Standard          2           7            130         910   Florence
# 19     Suite          3           7            195        1365  Barcelona
#
# ...

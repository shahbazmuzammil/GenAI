# %%
# Dataframe is sharing a different series with same index
import numpy as np
import pandas as pd
randomint=np.random.seed(101)
print(randomint)
myData= np.random.randint(0,101,(4,3))
myData
myIndex=['CY',"DY","AZ","TY"]
myColumn=['jan','feb',"mar"]
df=pd.DataFrame(myData,myIndex,myColumn)

# %%
pwd

# %%
ls

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas\\user.csv')
df.columns
df.describe().transpose()
print(df)
df[1:]

# %%
# type(df["StockQuantity"])
myCols = ['StockQuantity','Price']
df[myCols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # type(df["StockQuantity"])
#       2 myCols = ['StockQuantity','Price']
# ----> 3 df[myCols]
#
# NameError: name 'df' is not defined

# %%
df["percentage=price+Stock"]=df['Price']+df['StockQuantity']
df

# %%
df["percentage=price+Stock"]=np.round(df['Price'] / df['StockQuantity'],2)
df.drop(['Manufracturer'],axis=1)
# df.keys()
# df.shape()

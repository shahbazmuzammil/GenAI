# %%
import pandas as pd
df=pd.read_csv('c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas\\user.csv')

# df.sort_values(['Price','StockQuantity'],axis=1)
df.describe().transpose()
# df.sort_values(['Price','ProductID'])
# df['ProductID'].min()
#to get the lowest price contain row
# df.iloc[df['Price'].idxmin()]
# df.corr()
df['Price'].value_counts()
df['Price'].unique()
df['Price'].replace([19.99,25.50],[1,2])
# Out:
# 0      1.00
# 1      2.00
# 2     12.00
# 3     59.99
# 4     34.00
# 5     22.50
# 6     89.00
# 7     45.00
# 8     15.75
# 9     28.00
# 10     1.00
# 11     2.00
# 12    12.00
# 13    59.99
# 14    34.00
# 15    22.50
# 16    89.00
# 17    45.00
# 18    15.75
# 19    28.00
# Name: Price, dtype: float64

# %%
# myMap={19.99:5,25.50:9}
# df['Price'].map(myMap)
# simple_dup=pd.DataFrame([1,2,2,2],['a','b','c','d'])
# simple_dup.duplicated()
# # simple_dup.drop_duplicates()

# df[df['Price'].between("10","20",inclusive=True)]
df.nlargest(10,'Price')
df.iloc[df['Price'].idxmax()]
df.nsmallest(2,'Price')
# df.sort_values('Price',ascending=True).iloc[0:2]
df.sample(frac=0.1)
# Out:
#     ProductID           ProductName     Category  Price  StockQuantity  \
# 16        107  Bluetooth Headphones  Electronics  89.00             30
# 10        101       Classic T-Shirt      Apparel  19.99            120
#
#    Manufacturer
# 16     AudioPro
# 10  CottonWorks

# %%
import pandas as pd
import numpy as np


file=pd.read_csv("user.csv")
# file[file['Classic T-Shirt']== 'Classic T-Shirt']
# file[file[]]
# print(file[file['ProductName']=="Classic T-Shirt"])
# print(file[(file["Price"] > "15") | (file["StockQuantity"] < "180")])
# file
# print(price)
# file.info()
def last_four(num):
    return str(num)[1:]
# last_four(12345689)
## apply method allows to apply any costum fucntion on your dataset by using that you can alter or slice the clolumn value

file["new"]=file['StockQuantity'].apply(last_four)
file

file["Price"].mean()

def yelp(price):
    if price < 20:
        return "$"
    elif price >= 10 and price < 30 :
        return "$$"
    else:
        return "$$$"
    
file['yelp']=file["Price"].apply(yelp)
file['yelp']
file
# Out:
#     ProductID           ProductName     Category  Price  StockQuantity  \
# 0         101       Classic T-Shirt      Apparel  19.99            120
# 1         102        Wireless Mouse  Electronics  25.50             85
# 2         103           Ceramic Mug  Kitchenware  12.00            200
# 3         104         Running Shoes     Footwear  59.99             45
# 4         105         LED Desk Lamp       Office  34.00             60
# 5         106              Yoga Mat      Fitness  22.50            110
# 6         107  Bluetooth Headphones  Electronics  89.00             30
# 7         108        Leather Wallet  Accessories  45.00             55
# 8         109         Garden Shovel    Gardening  15.75             70
# 9         110      Coffee Beans 1kg      Grocery  28.00            150
# 10        101       Classic T-Shirt      Apparel  19.99            120
# 11        102        Wireless Mouse  Electronics  25.50             85
# ...

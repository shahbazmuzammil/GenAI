# %%
import pandas as pd
import numpy as np

df=pd.read_csv('c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas\\user.csv')
df.index
df.set_index('ProductName')

# df.reset_index()
# df.iloc[0:5]
# df.loc[["LED Desk Lamp"]]
# df.drop('Yoga Mat',axis=0)

df.iloc[1:4]
one_row=df.iloc[0]
one_row
app=df.a
app
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18876\788711513.py in ?()
#      12
#      13 df.iloc[1:4]
#      14 one_row=df.iloc[0]
#      15 one_row
# ---> 16 app=df.a
#      17 app
#      18
#      19
#
# c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'a'

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas\\user.csv')
df.index
df.set_index('ProductName')

# df.reset_index()
# df.iloc[0:5]
# df.loc[["LED Desk Lamp"]]
# df.drop('Yoga Mat',axis=0)

df.iloc[1:4]
one_row=df.iloc[0]
one_row
app=df
app
new_row = pd.DataFrame({'ProductName': ['Yoga Block'], 'Price': [15.99], 'Quantity': [5]})
df = pd.concat([df, new_row], ignore_index=True)
df.loc[len(df)] = {'ProductName': 'New Product', 'Price': 29.99}
df
row=pd.DataFrame({'ProductID':['111.0'],'Price':['2180'],'Manufacture':["cotton"],'Category':['Electronics']}) 
df = pd.concat([df,row],ignore_index=True)
df
# df.loc[len(df)] = {}
# Out:
#    ProductID           ProductName     Category  Price  StockQuantity  \
# 0      101.0       Classic T-Shirt      Apparel  19.99          120.0
# 1      102.0        Wireless Mouse  Electronics   25.5           85.0
# 2      103.0           Ceramic Mug  Kitchenware   12.0          200.0
# 3      104.0         Running Shoes     Footwear  59.99           45.0
# 4      105.0         LED Desk Lamp       Office   34.0           60.0
# 5      106.0              Yoga Mat      Fitness   22.5          110.0
# 6      107.0  Bluetooth Headphones  Electronics   89.0           30.0
# 7      108.0        Leather Wallet  Accessories   45.0           55.0
# 8      109.0         Garden Shovel    Gardening  15.75           70.0
# 9      110.0      Coffee Beans 1kg      Grocery   28.0          150.0
# 10     101.0       Classic T-Shirt      Apparel  19.99          120.0
# 11     102.0        Wireless Mouse  Electronics   25.5           85.0
# ...

# %%
import pandas as pd
df=pd.read_csv('c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas\\user.csv')

# df[df['StockQuantity'] > 70]
# df['SEX']=["MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE"]
# condi=df[(df["StockQuantity"] < 100) & (df["SEX"] == "MALE")]
# condi

# options = ['60','85']

check=df[df["StockQuantity"].isin(['60','85'])]
check
# df
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, Category, Price, StockQuantity, Manufacturer]
# Index: []

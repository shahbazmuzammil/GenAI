# %%
import pandas as pd
import numpy as np
my_index = ["USA","Xnanda","IK" ]
my_array = [0,1,2]
# np.arange(0,4).shape(1)
ass = pd.Series(data=my_array,index=my_index)
ass["IK"]
# Out:
# np.int64(2)

# %%
age={"jhon":5,"frank":20,"spike":9}

pd.Series(age)
# Out:
# jhon      5
# frank    20
# spike     9
# dtype: int64

# %%
#Dataframe
q1={"brazil":256,"africa":534,"USA":546,"CHINA":2454}

q2={"brazil":256,"africa":534,"USA":546,"CHINA":2454}
sr1=pd.Series(q2)
sr2=pd.Series(q2)
# data=pd.DataFrame()

sr1 * 100
sr1 + sr2
# Out:
# brazil     512
# africa    1068
# USA       1092
# CHINA     4908
# dtype: int64

# %%
sr1["brazil"]
sr1.keys()
# Out:
# Index(['brazil', 'africa', 'USA', 'CHINA'], dtype='object')

# %%
first_half=sr2.add(sr1,fill_value=0)


print(first_half)
# Out:
# brazil     512
# africa    1068
# USA       1092
# CHINA     4908
# dtype: int64

# %%
my_data=np.random.randint(0,101,(4,3))
print(my_data)

myindex=['CA','NY','TX','FL']
my_columns=['Jan','Feb','Mar']
df=pd.DataFrame(my_data,myindex,my_columns)
print(df)
# Out:
# [[36 80 91]
#  [27 80 27]
#  [88 81 23]
#  [56 37 88]]
#     Jan  Feb  Mar
# CA   36   80   91
# NY   27   80   27
# TX   88   81   23
# FL   56   37   88

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}
df = pd.DataFrame(data)

# Accessing a column
print(df['Name']) 

# Accessing the first row
print(df.iloc[0])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
pwd
# Out:
# 'c:\\Users\\l\\OneDrive\\Documents\\GenAIPython\\Pandas'

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 4019-E854
#
#  Directory of c:\Users\l\OneDrive\Documents\GenAIPython\Pandas
#
# 15/01/2026  16:17    <DIR>          .
# 15/01/2026  14:30    <DIR>          ..
# 15/01/2026  17:15            12,355 DateFrame.ipynb
# 24/01/2026  14:45            26,868 Pandas.ipynb
# 04/01/2026  21:00             1,713 Pandas_excercise.ipynb
# 15/01/2026  17:05             1,057 user.csv
#                4 File(s)         41,993 bytes
#                2 Dir(s)  149,010,157,568 bytes free

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
import pandas as pd
file=pd.read_csv('user.csv')
# file.to_string()
# file.columns()
# file.head()
# file.tail()
# file.info()
file.describe().transpose()
# file
file=file.set_index('gender')
# file.index
file
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31636\937835555.py in ?()
#       6 # file.tail()
#       7 # file.info()
#       8 file.describe().transpose()
#       9 # file
# ---> 10 file=file.set_index('gender')
#      11 # file.index
#      12 file
#      13
#
# c:\Users\l\OneDrive\Documents\GenAIPython\venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['gender'] are in the columns"

# %%
# file.head()
file.reset_index() 
# file=file.set_index('gender')
file.loc['Male'] ## for known 
file.iloc[9] ## unkonwn
# Out:
# first_name                      Misti
# last_name                      Fillan
# email         mfillan9@friendfeed.com
# ip_address               116.231.5.10
# date                        2/21/2017
# Name: Female, dtype: object

# %%
file.iloc[3:5]
# Out:
#        first_name last_name                 email      ip_address        date
# gender
# Male         Arvy    Lempke  alempke3@squidoo.com  117.227.52.135  10/20/2017
# Female       Cody     Jakov        cjakov4@i2i.jp  172.197.66.100   5/23/2017

# %%
# fd=file.drop("Male",axis=1)
# print(fd)
file
# one_row=file.iloc[0]
# print(one_row)
# file.insert(one_row)
# Out:
#        first_name  last_name                     email      ip_address  \
# gender
# Female    Roobbie    Wilbore    rwilbore0@bandcamp.com   82.243.17.211
# Female  Aprilette       Dole     adole1@altervista.org   12.132.123.75
# Male     Phillipe  Winkworth     pwinkworth2@wufoo.com   71.62.119.246
# Male         Arvy     Lempke      alempke3@squidoo.com  117.227.52.135
# Female       Cody      Jakov            cjakov4@i2i.jp  172.197.66.100
# ...           ...        ...                       ...             ...
# Female       Roxy   Adolfson  radolfsong@xinhuanet.com    81.86.118.11
# Female     Catlee     Covert      crth@liveinternet.ru    178.94.55.68
# Female    Raquela    Authers      rauthersi@seesaa.net   36.105.40.130
# Male       Josias     Currum       jcurrumj@meetup.com   39.200.104.21
# Male       Wyndhm    Hullins            whul@github.io  201.148.141.37
#
#               date
# gender
# Female    1/7/2018
# Female   3/27/2017
# Male     1/20/2018
# ...

# %%
type(file['email'])
# Out:
# pandas.core.series.Series

# %%
mycols=['email','gender','date']
file[['email','gender','date']]
file.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 mycols=['email','gender','date']
# ----> 2 file[['email','gender','date']]
#       3 file.columns
#
# NameError: name 'file' is not defined

# %%
file['uniquegender']=file['date'] + file['date']
print(file.head())
# Out:
#   first_name  last_name                   email  gender      ip_address  \
# 0    Roobbie    Wilbore  rwilbore0@bandcamp.com  Female   82.243.17.211
# 1  Aprilette       Dole   adole1@altervista.org  Female   12.132.123.75
# 2   Phillipe  Winkworth   pwinkworth2@wufoo.com    Male   71.62.119.246
# 3       Arvy     Lempke    alempke3@squidoo.com    Male  117.227.52.135
# 4       Cody      Jakov          cjakov4@i2i.jp  Female  172.197.66.100
#
#          date          uniquegender
# 0    1/7/2018      1/7/20181/7/2018
# 1   3/27/2017    3/27/20173/27/2017
# 2   1/20/2018    1/20/20181/20/2018
# 3  10/20/2017  10/20/201710/20/2017
# 4   5/23/2017    5/23/20175/23/2017

# %%
# file.drop('uniquegender',axis=1,)
# file.drop('uniquegender',axis=1)
# file=file.drop('uniquegender',axis=1)
# print(file)
# file.shape()
file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       1 # file.drop('uniquegender',axis=1,)
#       2 # file.drop('uniquegender',axis=1)
#       3 # file=file.drop('uniquegender',axis=1)
#       4 # print(file)
#       5 # file.shape()
# ----> 6 file
#
# NameError: name 'file' is not defined

# %%
file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file
#
# NameError: name 'file' is not defined

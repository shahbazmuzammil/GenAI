# %%
print("bismillah")
print(9*2+5)
# Out:
# bismillah
# 23

# %%
print ("heyyy")
# Out:
# heyyy

# %%
print(age)
name = 'shahbaz'
age =  28
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(age)
#       2 name = 'shahbaz'
#       3 age =  28
#
# NameError: name 'age' is not defined

# %%
###hellow
nhbcjhbajsbhc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 ###hellow
# ----> 2 nhbcjhbajsbhc
#
# NameError: name 'nhbcjhbajsbhc' is not defined

# %%
age=32
if age != 30:
        print(age)
print(age)
# Out:
# 32
# 32

# %%
##Multiple Statment an a single line 
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Semantic in Python
age=32
name="shahbaz"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type inference
variable=10
print(type(variable))
variable="shahbaz"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##Type Conversion
age=25
str(25)
## If age is in string and content letter not an base 10 numbe rit will not convert 
age="shahbaz"
# int(age)
## if float is is covert it to int 
number = 3
int(number)
## if flaot is covert it to string 
# str(number)
# '3.14'
# int convertit to float
day=3.2
int(number)
float(number)
# Out:
# 3.0

# %%
age=str(input("what is ypur age"))
print(age,type(age))
# Out:
# 28 <class 'str'>

# %%
num=int(input("please enter your 1 num"))
num2=int(input("pleaseenter your num 2 "))

plus = num+num2
print(plus)
